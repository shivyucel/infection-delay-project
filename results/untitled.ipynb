# %%
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "Serif"
import os
from multiprocessing import Pool
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rc('figure', dpi=200)
import glob
import pandas as pd
import seaborn as sns
import sys
from scipy.cluster.hierarchy import fcluster
import scipy.stats as stats
from tslearn.clustering import TimeSeriesKMeans
# Out:
# /Users/shivyucel/anaconda3/envs/geo_env/lib/python3.9/site-packages/tslearn/bases/bases.py:15: UserWarning: h5py not installed, hdf5 features will not be supported.
# Install h5py to use hdf5 features: http://docs.h5py.org/
#   warn(h5py_msg)

# %%
data_path = '/Users/shivyucel/Documents/SDS_2021.nosync/SDS_2020-2021/SDS_Thesis/Data/h3/'
populations = np.loadtxt(data_path + 'SIR/v1_populations.txt')
populations = pd.Series(populations)
pop_1500 = populations.sort_values(ascending = False).index

demographics = pd.read_csv(data_path + '/demographics/h3_demographic.csv')
income = pd.read_csv(data_path + '/demographics/h3_income.csv')
pop = pd.read_csv(data_path + '/population/h3_pop.csv')
zones = np.loadtxt(data_path + '/commuting/lst_of_zones.csv', delimiter=',')
hex_ids = pd.read_csv(data_path + '/commuting/h3_IDs.csv')

# %%
pops = pd.read_csv(data_path + '/population/h3_pop.csv')
demo = pd.read_csv(data_path + '/demographics/h3_demographic.csv')

# %%
data_path = '/Users/shivyucel/Documents/SDS_2021.nosync/SDS_2020-2021/SDS_Thesis/Data/'
commute = pd.DataFrame(np.loadtxt(data_path + f"h3/commuting/real_commuting_for_ED.csv", delimiter=","))
zones = np.array(commute[0].unique())


in_degree = pd.DataFrame(np.loadtxt(data_path + f"h3/commuting/real_commuting_for_ED.csv", delimiter=","))
in_degree.rename(columns={0: 'SOURCE', 1: 'TARGET', 2:'FLUX'}, inplace=True)
in_degree.drop_duplicates(['SOURCE', 'TARGET'], inplace=True)
in_degree = pd.DataFrame(in_degree.groupby('TARGET').count()).reset_index()
in_degree = in_degree[['TARGET', 'FLUX']]

# %%
files = glob.glob('/Volumes/harddrive/Data/real_commute_concat/*')
files.sort()

# %% [markdown]
# ## Get Weighted Infection Delay Values

# %%
grouped = pd.DataFrame()
in_d_med = in_degree['FLUX'].median()

for file in files:
    df = pd.read_csv(file)
    df.drop('Unnamed: 0', axis=1, inplace=True)
    df.columns = df.columns.astype(int)


    df.columns = zones[df.columns]
    merged = pd.DataFrame(df.columns).merge(in_degree, left_on=0, right_on='TARGET')


    norm = merged['FLUX'] / in_d_med
    weighted_time_saved = df * norm.values
    median_timesaved = weighted_time_saved.median(axis=1)
    grouped[f'{file.split(".")[0].split("/")[-1]}'] = median_timesaved
    print("done")
# Out:
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ...

# %%
    grouped.columns = grouped.columns.astype(int)
    grouped = grouped.reindex(sorted(grouped.columns), axis=1)
    grouped.columns = zones[grouped.columns]
    grouped.columns = hex_ids[hex_ids['0'].isin(grouped.columns)]['Unnamed: 0'].values

# %%
#grouped.to_csv('/Users/shivyucel/Documents/SDS_2021.nosync/SDS_2020-2021/SDS_Thesis/Data/infection_delay_weighted.csv')

# %% [markdown]
# ## Get Unweighted Infection Delay Values

# %%
grouped = pd.DataFrame()
for file in files:
    df = pd.read_csv(file)
    df.drop('Unnamed: 0', axis=1, inplace=True)
    df.columns = df.columns.astype(int)
    median_timesaved = df.median(axis=1)
    grouped[f'{file.split(".")[0].split("/")[-1]}'] = median_timesaved
    print("done")
# Out:
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ...

# %%
grouped.columns = grouped.columns.astype(int)
grouped = grouped.reindex(sorted(grouped.columns), axis=1)

# %%
grouped.columns = zones[grouped.columns]

# %%
grouped.columns = hex_ids[hex_ids['0'].isin(grouped.columns)]['Unnamed: 0'].values

# %%
#grouped.to_csv('/Users/shivyucel/Documents/SDS_2021.nosync/SDS_2020-2021/SDS_Thesis/Data/infection_delay_unweighted.csv')

# %% [markdown]
# ## Get High and Low Outbreak Centrality Infection Delays

# %%
in_degree = pd.DataFrame(np.loadtxt(data_path + f"h3/commuting/real_commuting_for_ED.csv", delimiter=","))
in_degree.rename(columns={0: 'SOURCE', 1: 'TARGET', 2:'FLUX'}, inplace=True)
in_degree.drop_duplicates(['SOURCE', 'TARGET'], inplace=True)
in_degree = pd.DataFrame(in_degree.groupby('TARGET').count()).reset_index()
in_degree = in_degree[['TARGET', 'FLUX']]

# %%
zones = np.array(commute[0].unique())
in_degree = in_degree[in_degree['TARGET'].isin(zones)]

in_degree['bin'] = ['low_degree' if x < in_degree['FLUX'].median() else 'high_degree' for x in in_degree['FLUX']]

low_degree = in_degree[in_degree['bin'] == 'low_degree']
high_degree = in_degree[in_degree['bin'] == 'high_degree']

low_degree = low_degree['TARGET'].values
high_degree = high_degree['TARGET'].values

# %%
in_degree['bin'] = pd.qcut(in_degree['FLUX'], q=2, labels=['low_degree', 'high_degree'])

low_degree = in_degree[in_degree['bin'] == 'low_degree']
high_degree = in_degree[in_degree['bin'] == 'high_degree']

# %%
df = pd.read_csv('/Users/shivyucel/Documents/SDS_2021.nosync/SDS_2020-2021/SDS_Thesis/Thesis_Code/data_summaries/infection_delay_unweighted.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)

df = pd.read_csv(file)
df.drop('Unnamed: 0', axis=1, inplace=True)
df.columns = df.columns.astype(int)
df = df.reindex(sorted(df.columns), axis=1)

# %%
grouped_low = pd.DataFrame()
grouped_high = pd.DataFrame()


for file in files:

    df = pd.read_csv(file)
    df.drop('Unnamed: 0', axis=1, inplace=True)
    df.columns = df.columns.astype(int)
    df = df.reindex(sorted(df.columns), axis=1)
    
    dest_zone = int(files[0].split(".")[0].split("/")[-1])
    temp_zones = np.delete(zones, dest_zone)
    df.columns = temp_zones

    low_inf_del = df[df.columns[df.columns.isin(low_degree['TARGET'])]]
    high_inf_del = df[df.columns[df.columns.isin(high_degree['TARGET'])]]

    mean_low = low_inf_del.mean(axis=1)
    mean_high = high_inf_del.mean(axis=1)

    grouped_low[f'{file.split(".")[0].split("/")[-1]}'] = mean_low
    grouped_high[f'{file.split(".")[0].split("/")[-1]}'] = mean_high

# %%
grouped_low.columns = grouped_low.columns.astype(int)
grouped_low = grouped_low.reindex(sorted(grouped_low.columns), axis=1)

grouped_high.columns = grouped_high.columns.astype(int)
grouped_high = grouped_high.reindex(sorted(grouped_high.columns), axis=1)

grouped_low.columns = zones[grouped_low.columns]
grouped_high.columns = zones[grouped_high.columns]
grouped_low_hex = pd.DataFrame(grouped_low.columns).merge(hex_ids, left_on=0, right_on='0').rename(columns={'Unnamed: 0': 'hexids'})
grouped_high_hex = pd.DataFrame(grouped_high.columns).merge(hex_ids, left_on=0, right_on='0').rename(columns={'Unnamed: 0': 'hexids'})

# %%
grouped_low.to_csv('/Volumes/harddrive/Data/outbreak_bins/low_bins/v2_grouped_low.csv')
grouped_high.to_csv('/Volumes/harddrive/Data/outbreak_bins/low_bins/v2_grouped_high.csv')
